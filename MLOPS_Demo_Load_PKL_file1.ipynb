# %% [markdown]
# <a href="https://colab.research.google.com/github/ehurtos/MLOPS/blob/main/MLOPS_Demo_Load_PKL_file1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pickle
import numpy as np
from sklearn.datasets import load_iris

#  install required version of environments
! pip install -r requirements.txt

# Change to the desired directory
# %cd /content/sample_data

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Load the trained model and make inference
def predict(input_features):
    # Construct the full path to the model file
    model_path = os.path.join(os.getcwd(), "iris_model.pkl")

    try:
        with open(model_path, "rb") as f:
            loaded_model = pickle.load(f)
    except FileNotFoundError:
        print(f"Error: Model file not found at {model_path}")
        return None  # Or raise an exception if preferred

    # Reshape input_features to a 2D array with one row
    input_features = input_features.reshape(1, -1)

    prediction = loaded_model.predict(input_features)
    return iris.target_names[prediction[0]]

# Example input for inference
sample_input = np.array([5.1, 3.5, 1.4, 0.2])

result = predict(sample_input)

if result is not None:
    print(f"Prediction: {result}")
# Out:
# ...
# INFO: pip is looking at multiple versions of tensorflow to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install -r requirements.txt (line 2), -r requirements.txt (line 3), -r requirements.txt (line 4), -r requirements.txt (line 5), -r requirements.txt (line 6) and numpy==1.26.4 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested numpy==1.26.4
#     pandas 2.0.3 depends on numpy>=1.21.0; python_version >= "3.10"
#     pandas 2.0.3 depends on numpy>=1.23.2; python_version >= "3.11"
#     scikit-learn 1.3.0 depends on numpy>=1.17.3
#     matplotlib 3.7.2 depends on numpy>=1.20
#     seaborn 0.12.2 depends on numpy!=1.24.0 and >=1.17
#     tensorflow 2.13.0 depends on numpy<=1.24.3 and >=1.22
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# ...
