# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

# Define the start and end dates for the given date range
start_date = '2020-12-01'
end_date = '2021-03-01'

# Filter the Landsat 8 collection to the given date range.
# The end date is exclusive.
image_collection = ee.ImageCollection(
    'LANDSAT/LC08/C02/T1').filterDate(start_date, end_date)

# Calculate the median composite
median_composite = image_collection.median()

# Display the median composite on the map
m.add_layer(
    median_composite,
    {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max':30000},
    'Median Composite')
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-1-b0aebcbe4e07> in <cell line: 0>()
#       1 import ee
#       2 import geemap
# ----> 3 ee.Initialize()
#       4 m = geemap.Map()
#       5
#
# /usr/local/lib/python3.11/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
#      37             kwargs[new_key] = old_key_val
# ---> 38       return func(*args, **kwargs)
#      39
#      40     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/ee/__init__.py in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     183   """
#     184   if credentials == 'persistent':
# --> 185     credentials = data.get_persistent_credentials()
#     186   if not project and credentials and hasattr(credentials, 'quota_project_id'):
#     187     project = credentials.quota_project_id
#
# /usr/local/lib/python3.11/dist-packages/ee/data.py in get_persistent_credentials()
#     279     if oauth.is_valid_credentials(credentials):
#     280       return credentials
# --> 281   raise ee_exception.EEException(  # pylint: disable=raise-missing-from
#     282       'Please authorize access to your Earth Engine account by '
#     283       'running\n\nearthengine authenticate\n\n'
#
# EEException: Please authorize access to your Earth Engine account by running
#
# earthengine authenticate
#
# in your command line, or ee.Authenticate() in Python, and then retry.
